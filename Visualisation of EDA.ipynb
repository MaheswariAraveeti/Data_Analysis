# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("HyperAuditor.csv")

# %%
df
# Out:
#      Unnamed: 0  Rank          Channel        Country         Category  \
# 0             0     1          tseries          India    Music & Dance
# 1             1     2          MrBeast  United States      Video games
# 2             7     8  zeemusiccompany          India    Music & Dance
# 3             8     9              WWE  United States      Video games
# 4             9    10        BLACKPINK  United States    Music & Dance
# ..          ...   ...              ...            ...              ...
# 412         695   696        ladydiana         Russia    Music & Dance
# 413         696   697           Wengie  United States    Food & Drinks
# 414         697   698          gmanews    Philippines  News & Politics
# 415         698   699           Anaysa          India           Movies
# 416         699   700       PozziGamer         Russia        Animation
#
#      Followers    Viewers    Likes  Comments
# 0    247100000     103800     2800       101
# ...

# %%
df1=df.drop("Unnamed: 0",axis=1)

# %%
df1
# Out:
#      Rank          Channel        Country         Category  Followers  \
# 0       1          tseries          India    Music & Dance  247100000
# 1       2          MrBeast  United States      Video games  174000000
# 2       8  zeemusiccompany          India    Music & Dance   97700000
# 3       9              WWE  United States      Video games   96600000
# 4      10        BLACKPINK  United States    Music & Dance   90500000
# ..    ...              ...            ...              ...        ...
# 412   696        ladydiana         Russia    Music & Dance   13600000
# 413   697           Wengie  United States    Food & Drinks   13600000
# 414   698          gmanews    Philippines  News & Politics   13600000
# 415   699           Anaysa          India           Movies   13600000
# 416   700       PozziGamer         Russia        Animation   13600000
#
#        Viewers    Likes  Comments
# 0       103800     2800       101
# 1    145500000  8700000     18300
# ...

# %%
df1["Viewers"].max()
# Out:
# 145500000

# %% [markdown]
# ### univariate variables

# %%
### hist plot
plt.hist(df1["Followers"],bins=10)
plt.xlabel("Follwers")
plt.ylabel("Frequency")
plt.title("Histogram of Followers")
plt.show()

# %%
plt.hist(df1["Likes"],bins=10)
plt.xlabel("Likes")
plt.ylabel("Frequency")
plt.title("Histogram of Likes")
plt.show()

# %%
plt.hist(df1["Viewers"],bins=10)
plt.xlabel("Viewers")
plt.ylabel("Frequency")
plt.title("Histogram of Viewers")
plt.show()

# %%
plt.hist(df1["Comments"],bins=10)
plt.xlabel("Comments")
plt.ylabel("Frequency")
plt.title("Histogram of Comments")
plt.show()

# %%
sns.kdeplot(x="Followers",data=df1)
plt.xlabel("followerss")
plt.ylabel("Freqency")
plt.title("Density plot of followers")
plt.show()

# %%
sns.kdeplot(x="Viewers",data=df1)
plt.xlabel("Viewers")
plt.ylabel("Freqency")
plt.title("Density plot of viewers")
plt.show()

# %%
sns.kdeplot(x="Likes",data=df1)
plt.xlabel("Likes")
plt.ylabel("Freqency")
plt.title("Density plot of Likes")
plt.show()

# %%
sns.kdeplot(x="Comments",data=df1)
plt.xlabel("Comments")
plt.ylabel("Freqency")
plt.title("Density plot of Comments")
plt.show()

# %%
df1["Channel"].value_counts()
# Out:
# A                  2
# tseries            1
# IanLucasOficial    1
# DopeLyrics         1
# Arifmuhammadd      1
#                   ..
# charlieputh        1
# ishaanali          1
# StokesTwins        1
# BenAzelart         1
# PozziGamer         1
# Name: Channel, Length: 416, dtype: int64

# %%
ax=df1["Category"].value_counts().plot.bar()
plt.title("Bargraph of Category")
plt.xlabel("Category")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=6, color='black')

plt.tight_layout()
plt.show()

# %%
ax=df1["Country"].value_counts().plot.bar()
plt.title("Bargraph of Country")
plt.xlabel("Country")


for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=6, color='black')

plt.tight_layout()
plt.show()

# %%
df1["Country"].value_counts().plot.pie(autopct="%1.2f%%",radius=3)
plt.xlabel("Country")
#plt.title("Piechart of Country")
plt.show()

# %%
df1["Category"].value_counts().plot.pie(autopct="%1.2f%%",radius=3.5)
plt.xlabel("Category")
#plt.title("Piechart of Categotry")
plt.show()

# %%
plt.subplot(2,2,1)
plt.hist(df1["Followers"],bins=10)
plt.xlabel("Follwers")
plt.ylabel("Frequency")
plt.title("Histogram of Followers")
plt.show()
plt.subplot(2,2,2)
plt.hist(df1["Likes"],bins=10)
plt.xlabel("Likes")
plt.ylabel("Frequency")
plt.title("Histogram of Likes")
plt.show()
plt.subplot(2,2,3)
plt.hist(df1["Viewers"],bins=10)
plt.xlabel("Viewers")
plt.ylabel("Frequency")
plt.title("Histogram of Viewers")
plt.show()
plt.subplot(2,2,4)
plt.hist(df1["Comments"],bins=10)
plt.xlabel("Comments")
plt.ylabel("Frequency")
plt.title("Histogram of Comments")
plt.show()

# %%
#plt.subplot(221)
sns.displot(df1["Followers"],kde=True)
#plt.xlabel("followerss")
#plt.ylabel("Freqency")
plt.title("Density plot of followers")
plt.show()
#plt.subplot(222)
sns.displot(df1["Viewers"],kde=True)
#plt.xlabel("viewers")
#plt.ylabel("Freqency")
plt.title("Density plot of viewers")
plt.show()
#plt.subplot(221)
sns.displot(df1["Likes"],kde=True)
#plt.xlabel("Likess")
#plt.ylabel("Freqency")
plt.title("Density plot of likes")
plt.show()
#plt.subplot(224)
sns.displot(df1["Comments"],kde=True)
#plt.xlabel("comments")
#plt.ylabel("Freqency")
plt.title("Density plot of comments")
plt.show()

# %%
plt.subplot(221)
df1["Country"].value_counts().plot.pie(autopct="%1.2f%%",radius=3)
plt.xlabel("Country")
plt.title("Piechart of Country")
plt.suptitle("pie charts of Country and category")
plt.show()
plt.show()
plt.subplot(222)
df1["Category"].value_counts().plot.pie(autopct="%1.2f%%",radius=3)
plt.xlabel("Category")
plt.title("Piechart of Categotry")
#plt.suptitle("pie charts of Country and category")
plt.show()

# %%
plt.subplot(2,2,1)
plt.boxplot(df1["Followers"],vert=True,patch_artist=True)
plt.title("Followers of Box plot")
plt.subplot(2,2,2)
plt.boxplot(df1["Comments"],vert=True,patch_artist=True)
plt.title("Comments of Box plot")
plt.subplot(2,2,3)
plt.boxplot(df1["Viewers"],vert=True,patch_artist=True)
plt.title("Viewers of Box plot")
plt.subplot(2,2,4)
plt.boxplot(df1["Likes"],vert=True,patch_artist=True)
plt.title("Likes of Box plot")
plt.show()

# %%
plt.subplot(221)
ax=df1["Category"].value_counts().plot.bar()
plt.title("Bargraph of Category")
plt.xlabel("Category")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=6, color='black')

plt.tight_layout()
plt.show()
plt.subplot(222)
ax1=df1["Country"].value_counts().plot.bar()
plt.title("Bargraph of Country")
plt.xlabel("Country")


for p in ax.patches:
    ax1.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=6, color='black')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
#plt.figure(figsize=(10,4))
ax=sns.countplot(x='Category', data=df1)
plt.title("Categorys")
plt.xticks(rotation=90)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=6, color='black')

plt.tight_layout()
plt.show()
plt.subplot(222)
#plt.figure(figsize=(10,4))
ax1=sns.countplot(x='Country', data=df1)
plt.title("Countrys")
plt.xticks(rotation=90)
for p in ax.patches:
    ax1.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=6, color='black')

plt.tight_layout()
plt.show()

# %%
sns.boxplot(x="Category", y="Followers", data=df1)
plt.title('Category of Followers')
plt.ylabel('Followers')
plt.xlabel('Category')
plt.xticks(rotation = 90)
plt.show()

# %%
groupby = df1.groupby('Category')[["Followers"]].mean()
groupby.head(2)
# Out:
#                  Followers
# Category
# ASMR            15200000.0
# Animals & Pets  15399999.5

# %%
groupby.plot(kind="bar", stacked=False,color="gray")
plt.ylabel("Mean")
plt.show()

# %%
x=list(np.arange(len(sam.index)))
plt.xticks(x,sam.index)

plt.bar(x,sam.Followers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 x=list(np.arange(len(sam.index)))
#       2 plt.xticks(x,sam.index)
#       4 plt.bar(x,sam.Followers)
#
# NameError: name 'sam' is not defined

# %%
pd.pivot_table(df1,index=["Country","Category"],values="Viewers")
# Out:
#                                          Viewers
# Country       Category
# Argentina     Animation             2.800000e+06
#               Movies                1.918225e+06
# Bangladesh    Daily vlogs           7.000000e+03
#               News & Politics       4.100000e+03
#               Travel                1.372000e+05
# ...                                          ...
# United States News & Politics       5.173333e+04
#               Science & Technology  2.406717e+06
#               Sports                1.035250e+05
#               Toys                  4.340000e+04
#               Video games           9.067195e+06
#
# [85 rows x 1 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df1[df1["Country"]=="Argentina"]["Category"].unique()
# Out:
# array(['Animation', 'Movies'], dtype=object)

# %%
df1
# Out:
#      Rank                   Channel         Country              Category  \
# 0       1                   tseries           India         Music & Dance
# 1       2                   MrBeast   United States           Video games
# 2       8           zeemusiccompany           India         Music & Dance
# 3       9                       WWE   United States           Video games
# 4      10                 BLACKPINK   United States         Music & Dance
# 5      11                   SonySAB           India                Movies
# 6      13                       BTS           India         Music & Dance
# 7      14                HYBELABELS   United States         Music & Dance
# 8      17                 KondZilla          Brazil         Music & Dance
# 9      19                filmigaane           India         Music & Dance
# 10     21        TSeriesBhaktiSagar           India         Music & Dance
# 11     22              tipsofficial           India         Music & Dance
# ...

# %%
df1
# Out:
#      Rank                   Channel         Country              Category  \
# 0       1                   tseries           India         Music & Dance
# 1       2                   MrBeast   United States           Video games
# 2       8           zeemusiccompany           India         Music & Dance
# 3       9                       WWE   United States           Video games
# 4      10                 BLACKPINK   United States         Music & Dance
# 5      11                   SonySAB           India                Movies
# 6      13                       BTS           India         Music & Dance
# 7      14                HYBELABELS   United States         Music & Dance
# 8      17                 KondZilla          Brazil         Music & Dance
# 9      19                filmigaane           India         Music & Dance
# 10     21        TSeriesBhaktiSagar           India         Music & Dance
# 11     22              tipsofficial           India         Music & Dance
# ...

# %%
plt.hist([df1['Followers'], df1['Viewers']], bins=5, label=['Followers', 'Viewers'])
plt.legend()
plt.title("Followers vs Viewers")
plt.show()

# %%
sns.pairplot(df1)

# %%
sns.heatmap(df1.corr(),annot=True,fmt=".2f")
plt.show()
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_23244\597003569.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True,fmt=".2f")

# %%
#colors_p = ['red','green','blue','pink','black','pink','brown']
#colors_ps = [np.random.choice(colors_p) for i in range(7)]

# %%
plt.scatter(df1['Comments'],df1['Likes'])
plt.title("Comments VS Likes")
plt.xlabel("Comments")
plt.ylabel("Likes")
plt.show()

# %%
plt.figure(dpi = 100, figsize=(15,10))
df1.groupby(['Country']["Category"])['Followers'].min().plot(kind = 'pie',autopct="%1.2f%%",radius=2)
plt.show()
# Out:
# <>:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_23244\777384689.py:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   df1.groupby(['Country']["Category"])['Followers'].min().plot(kind = 'pie',autopct="%1.2f%%",radius=2)
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_23244\777384689.py:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   df1.groupby(['Country']["Category"])['Followers'].min().plot(kind = 'pie',autopct="%1.2f%%",radius=2)
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_23244\777384689.py:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# ...

# %%
plt.figure(dpi = 100, figsize=(200,200))
df1.groupby(['Country','Category'])['Followers'].agg(["min","max"]).plot(kind = 'bar');
#for p in ax.patches:
    #ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                #ha='center', va='bottom', fontsize=6, color='black')

#plt.tight_layout()

# %%
ax=df1.groupby("Category")["Viewers"].agg(["min","max"]).plot(kind="bar")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=6, color='black')

plt.tight_layout()

# %%
pd.crosstab(index=df1["Category"],columns=df1["Comments"]).plot(kind="bar",stacked=True).legend(bbox_to_anchor=(1,1),fontsize='small')

# %%
pd.crosstab(index=df1["Country"],columns=df1["Category"]).plot(kind="bar",stacked=True).legend(bbox_to_anchor=(1,1),fontsize='small')

# %%
plt.style.use("ggplot")
df1.groupby("Country")["Followers"].agg(["min","max"]).plot(kind="bar")

#for p in ax.patches:
    #ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                #ha='center', va='bottom', fontsize=6, color='black')

#plt.tight_layout()
#plt.show()
# Out:
# <Axes: xlabel='Country'>

# %%
plt.figure(figsize=(8,8))
plt.pie(df1["Country"].value_counts()[:10],labels=df1["Country"].value_counts()[:10].index,autopct="%0.2f%%")
plt.show()

# %%
import plotly.express as ex
import plotly.graph_objects as go

# %%
df1[df["Followers"]==df1["Followers"].min()]
# Out:
#      Rank            Channel        Country         Category  Followers  \
# 407   688  ZeinabHarakeVlogs    Philippines            Humor   13600000
# 408   690   awakeningrecords      Indonesia    Music & Dance   13600000
# 409   691               BUDI      Indonesia           Movies   13600000
# 410   692  blockbustermovies          India      Daily vlogs   13600000
# 411   693       TypicalGamer  United States      Video games   13600000
# 412   696          ladydiana         Russia    Music & Dance   13600000
# 413   697             Wengie  United States    Food & Drinks   13600000
# 414   698            gmanews    Philippines  News & Politics   13600000
# 415   699             Anaysa          India           Movies   13600000
# 416   700         PozziGamer         Russia        Animation   13600000
#
#      Viewers  Likes  Comments
# 407  2100000  79600      1600
# 408    11700    886        28
# 409   652100  24600      1200
# 410     8700    122         3
# ...

# %%
df1[df["Followers"]==df1["Followers"].max()]
# Out:
#    Rank  Channel Country       Category  Followers  Viewers  Likes  Comments
# 0     1  tseries   India  Music & Dance  247100000   103800   2800       101

# %%
df1["Category"].mode()
# Out:
# 0    Music & Dance
# Name: Category, dtype: object

# %%
df1.head()
# Out:
#    Rank          Channel        Country       Category  Followers    Viewers  \
# 0     1          tseries          India  Music & Dance  247100000     103800
# 1     2          MrBeast  United States    Video games  174000000  145500000
# 2     8  zeemusiccompany          India  Music & Dance   97700000     106300
# 3     9              WWE  United States    Video games   96600000     134700
# 4    10        BLACKPINK  United States  Music & Dance   90500000    1600000
#
#      Likes  Comments
# 0     2800       101
# 1  8700000     18300
# 2     4700        43
# 3     4000       190
# 4   180300      6100

# %%
df2=df1.groupby("Category")[["Viewers"]].sum()

# %%
df2
# Out:
#                         Viewers
# Category
# ASMR                     462900
# Animals & Pets          5013100
# Animation             126304100
# Autos & Vehicles         240400
# Beauty                  1000000
# DIY & Life Hacks        3094100
# Daily vlogs            46452900
# Design/art              6150800
# Education               1666200
# Fashion                  327100
# Fitness                  582000
# Food & Drinks          12024800
# Health & Self Help      3600000
# Humor                  15621299
# Movies                102944000
# Music & Dance          91563063
# News & Politics         1097900
# Science & Technology   15717000
# Sports                   988300
# Toys                      43400
# Travel                   137200
# Video games           219973800

# %%
df2.head()
# Out:
#                     Viewers
# Category
# ASMR                 462900
# Animals & Pets      5013100
# Animation         126304100
# Autos & Vehicles     240400
# Beauty              1000000

# %%
df2=df1[["Category"]].value_counts()

# %%
df2
# Out:
# Category
# Music & Dance           150
# Movies                   77
# Animation                58
# Video games              33
# News & Politics          27
# Daily vlogs              18
# Science & Technology     10
# Food & Drinks            10
# Education                 6
# Humor                     5
# Sports                    5
# Design/art                3
# DIY & Life Hacks          3
# Fashion                   2
# Fitness                   2
# Animals & Pets            2
# Health & Self Help        1
# Beauty                    1
# Autos & Vehicles          1
# Toys                      1
# Travel                    1
# ASMR                      1
# dtype: int64

# %%
df1["Category"].mode()
# Out:
# 0    Music & Dance
# Name: Category, dtype: object

# %%
df2.head()
# Out:
# Category
# Music & Dance      150
# Movies              77
# Animation           58
# Video games         33
# News & Politics     27
# dtype: int64

# %%
plt.scatter(df1['Followers'],df1['Viewers'])
plt.title("Followers VS Viewers")
plt.xlabel("Followers")
plt.ylabel("Viewers")
plt.show()
